# %% [markdown]
# # Notebook 01b — Baseline CRNN (Revised Preprocessing)

# %% [markdown]
# ##  Environment & configuration
#
# **MPS note (important for the thesis methodology section):** PyTorch's `nn.CTCLoss` has
# no native Metal (MPS) kernel, so we enable the official CPU fallback
# (`PYTORCH_ENABLE_MPS_FALLBACK=1`) **before importing torch**. The forward/backward pass
# of the network runs on the M-series GPU; only the (cheap) CTC loss computation falls back
# to CPU. This is the standard, documented workaround and costs little for word-sized inputs.
#
# **Understand for the viva:** why must the env var be set before `import torch`?
# (Because the MPS backend reads it once at library initialisation.)

# %%
import os
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"  # must precede `import torch`

import math
import random
import time
from dataclasses import dataclass
from pathlib import Path

import numpy as np
import pandas as pd
from PIL import Image, ImageOps

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt


# ---- Reproducibility -------------------------------------------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# ---- Device ----------------------------------------------------------------
if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
elif torch.cuda.is_available():
    DEVICE = torch.device("cuda")
else:
    DEVICE = torch.device("cpu")
print(f"Using device: {DEVICE} | torch {torch.__version__}")
# Out:
# Using device: mps | torch 2.12.0

# %%
@dataclass
class Config:
    """Single source of truth for every experimental knob.

    Keeping ALL hyperparameters here (rather than scattered through cells) means the
    thesis methodology table can be generated from one place, and experiments are
    reproducible from the saved config.
    """
    # --- Data: BD prescription dataset layout (edit paths for your machine) ---
    # Expected: a labels CSV with one row per image. Column names are configurable
    # so the SAME notebook runs on the custom pharmacy dataset later.
    data_root: Path = Path("../data/pharmacy_lk")
    train_csv: str = "splits/train.csv"
    train_img_dir: str = "images"
    val_csv: str = "splits/val.csv"
    val_img_dir: str = "images"
    test_csv: str = "splits/test.csv"
    test_img_dir: str = "images"
    img_col: str = "image_filename"
    label_col: str = "medicine_name"

    # --- Preprocessing (REVISED: fixed canvas, aspect-ratio preserving) ---
    img_height: int = 48            # taller than canonical 32 to preserve stroke detail
    img_width: int = 320            # FIXED width; every image padded to this (no stretching)
    pad_value: float = 1.0          # pad with white (images normalised to [0,1] first)

    # --- Model ---
    rnn_hidden: int = 256
    rnn_layers: int = 2
    dropout: float = 0.2

    # --- Training (REVISED: lower LR + warmup) ---
    batch_size: int = 64
    epochs: int = 120
    lr: float = 1e-4                # lowered from 3e-4 to settle the optimisation
    warmup_epochs: int = 5         # linear LR warmup avoids early divergence
    weight_decay: float = 1e-4
    grad_clip: float = 5.0
    early_stop_patience: int = 20  # stop if val CER has not improved for N epochs
    num_workers: int = 0            # keep modest on macOS
    ckpt_dir: Path = Path("../checkpoints/baseline_crnn_v2")

CFG = Config()
CFG.ckpt_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 3. Vocabulary and CTC label encoding
#
# CTC reserves index **0 for the blank symbol**; real characters start at index 1.
# The character set is built **from the training labels only** (building it from
# val/test would be a subtle form of information leakage worth mentioning in the
# methodology chapter).
#
# **Understand for the viva:** what does the CTC blank do? (It separates repeated
# characters and absorbs timesteps with no emission, enabling alignment-free training.)

# %%
class Vocab:
    """Bidirectional mapping char <-> index, with index 0 reserved for CTC blank."""

    BLANK = 0

    def __init__(self, texts):
        chars = sorted(set("".join(texts)))
        self.idx2char = {i + 1: c for i, c in enumerate(chars)}
        self.char2idx = {c: i for i, c in self.idx2char.items()}

    def __len__(self):
        return len(self.idx2char) + 1  # +1 for blank

    def encode(self, text: str) -> list[int]:
        return [self.char2idx[c] for c in text]

    def decode_greedy(self, indices: list[int]) -> str:
        """Collapse repeats, then drop blanks (standard CTC greedy decoding)."""
        out, prev = [], None
        for i in indices:
            if i != prev and i != self.BLANK:
                out.append(self.idx2char[i])
            prev = i
        return "".join(out)

# %% [markdown]
# ## 4. Dataset and preprocessing
#
# Pipeline per image: load → greyscale → resize to height 32 preserving aspect ratio →
# cap width → normalise to [0,1] → (train only) light augmentation → pad to batch width.
#
# Augmentation is deliberately conservative (small rotation/shear): aggressive geometric
# distortion can turn one medicine name into a look-alike of another, corrupting labels —
# a domain-specific risk worth a sentence in the thesis.
#
# **Understand for the viva:** why pad with white rather than black? (Prescription
# backgrounds are paper-white; padding should be indistinguishable from background so
# the CNN does not learn artificial edge features at pad boundaries.)

# %%
class WordImageDataset(Dataset):
    def __init__(self, csv_path: Path, img_dir: Path, cfg: Config,
                 vocab: Vocab | None = None, augment: bool = False):
        self.df = pd.read_csv(csv_path)
        # Defensive cleaning: drop rows with missing labels, coerce to str, strip spaces
        self.df = self.df.dropna(subset=[cfg.label_col])
        self.df[cfg.label_col] = self.df[cfg.label_col].astype(str).str.strip()
        self.img_dir = Path(img_dir)
        self.cfg = cfg
        self.augment = augment
        self.vocab = vocab  # set after construction for the training set

    def labels(self) -> list[str]:
        return self.df[self.cfg.label_col].tolist()

    def __len__(self):
        return len(self.df)

    def _load_and_resize(self, path: Path) -> Image.Image:
        """Resize preserving aspect ratio, then pad (NOT stretch) onto a fixed
        img_height x img_width white canvas. This keeps character proportions
        consistent across the wide range of source widths (128–1342 px), which the
        previous variable-width stretch destroyed — the main fix in this revision.
        """
        img = Image.open(path).convert("L")
        w, h = img.size
        # scale to target height, preserving aspect ratio
        new_w = max(1, int(round(w * self.cfg.img_height / h)))
        new_w = min(new_w, self.cfg.img_width)            # never exceed the canvas
        img = img.resize((new_w, self.cfg.img_height), Image.BILINEAR)
        # paste left-aligned onto a fixed-width white canvas (255 = white in L mode)
        canvas = Image.new("L", (self.cfg.img_width, self.cfg.img_height), color=255)
        canvas.paste(img, (0, 0))
        return canvas

    def _augment(self, img: Image.Image) -> Image.Image:
        # Small random rotation; fill exposed corners with white
        angle = random.uniform(-3.0, 3.0)
        return img.rotate(angle, resample=Image.BILINEAR, fillcolor=255)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = self._load_and_resize(self.img_dir / str(row[self.cfg.img_col]))
        if self.augment:
            img = self._augment(img)
        x = torch.from_numpy(np.array(img, dtype=np.float32) / 255.0).unsqueeze(0)  # (1,H,W)
        text = row[self.cfg.label_col]
        target = torch.tensor(self.vocab.encode(text), dtype=torch.long)
        # also return filename so evaluation can join the seen_in_train flag
        return x, target, text, str(row[self.cfg.img_col])


def collate(batch, pad_value: float):
    """All images are already a fixed size, so we just stack. Targets are
    concatenated for CTC. Filenames are carried through for seen/unseen analysis."""
    xs, targets, texts, fnames = zip(*batch)
    images = torch.stack(xs)                             # (N, 1, H, W) — fixed size
    target_lengths = torch.tensor([t.numel() for t in targets], dtype=torch.long)
    targets_cat = torch.cat(targets)                    # CTC takes concatenated targets
    return images, targets_cat, target_lengths, list(texts), list(fnames)

# %% [markdown]
# ## 5. The CRNN architecture
#
# The convolutional stack follows Shi et al. (2017): seven conv layers with pooling that
# halves width twice but height four times, so a 32-px-high input becomes a height-1
# feature map — i.e. a pure left-to-right feature **sequence** of width ≈ W/4. Two BiLSTM
# layers then model sequential context, and a linear head emits per-timestep character
# logits for CTC.
#
# **Understand for the viva (sequence-length arithmetic):** CTC requires
# `input_length ≥ target_length`. With `img_width=320`, the sequence length is
# 320/4 = 80 timesteps, far above the longest medicine-name label. Adaptive pooling
# collapses the vertical axis to 1 regardless of input height (32 or 48).

# %%
class CRNN(nn.Module):
    def __init__(self, n_classes: int, rnn_hidden: int = 256,
                 rnn_layers: int = 2, dropout: float = 0.2):
        super().__init__()

        def conv(in_c, out_c, bn=False):
            layers = [nn.Conv2d(in_c, out_c, 3, 1, 1)]
            if bn:
                layers.append(nn.BatchNorm2d(out_c))
            layers.append(nn.ReLU(inplace=True))
            return layers

        self.cnn = nn.Sequential(
            *conv(1, 64),    nn.MaxPool2d(2, 2),    # H x W   -> H/2  x W/2
            *conv(64, 128),  nn.MaxPool2d(2, 2),    #         -> H/4  x W/4
            *conv(128, 256), *conv(256, 256),
            nn.MaxPool2d((2, 1), (2, 1)),           #         -> H/8  x W/4 (height only)
            *conv(256, 512, bn=True), *conv(512, 512, bn=True),
            nn.MaxPool2d((2, 1), (2, 1)),           #         -> H/16 x W/4
        )
        # Collapse whatever vertical extent remains to height 1, leaving width (the
        # sequence axis) untouched. Using adaptive pooling makes the model robust to the
        # input height (works for 32 or 48 px) without re-deriving pooling by hand.
        self.collapse = nn.AdaptiveAvgPool2d((1, None))   # -> (N, 512, 1, W/4)
        self.rnn = nn.LSTM(
            input_size=512, hidden_size=rnn_hidden, num_layers=rnn_layers,
            bidirectional=True, dropout=dropout if rnn_layers > 1 else 0.0,
        )
        self.head = nn.Linear(2 * rnn_hidden, n_classes)

    def forward(self, x):                 # x: (N, 1, H, W)
        f = self.cnn(x)                   # (N, 512, H', W/4)
        f = self.collapse(f)              # (N, 512, 1, W/4)
        f = f.squeeze(2).permute(2, 0, 1) # (T, N, 512)  — sequence-first for LSTM/CTC
        seq, _ = self.rnn(f)              # (T, N, 2*hidden)
        return self.head(seq)             # (T, N, n_classes) — raw logits

    @staticmethod
    def output_lengths(input_widths: torch.Tensor) -> torch.Tensor:
        """Map padded image widths to CTC input_lengths (must mirror the CNN strides)."""
        return torch.div(input_widths, 4, rounding_mode="floor")

# %% [markdown]
# ### 5.1 Shape smoke test
# Always verify tensor shapes with a dummy batch before training — cheap insurance
# against silent broadcasting bugs (and good evidence of testing practice for the
# implementation subgrade).

# %%
_dummy = torch.randn(2, 1, CFG.img_height, CFG.img_width)
_model_tmp = CRNN(n_classes=40)
with torch.no_grad():
    _out = _model_tmp(_dummy)
print(f"Input {tuple(_dummy.shape)} -> logits {tuple(_out.shape)}  (T, N, C)")
assert _out.shape[1] == 2
del _model_tmp, _dummy, _out
# Out:
# Input (2, 1, 48, 320) -> logits (80, 2, 40)  (T, N, C)

# %% [markdown]
# ## 6. Metrics: CER, WER, Exact Match
#
# - **CER** (character error rate) = edit distance / reference length. The primary HTR
#   metric; sensitive to partial correctness.
# - **Exact Match Accuracy** — the clinically meaningful metric here: a medicine name
#   that is 90% correct may still be the *wrong drug* (look-alike names), so partial
#   credit is misleading for deployment claims.
# - **WER** — for single-word samples, WER = 1 − exact match; reported for comparability
#   with multi-word literature.
#
# Implemented dependency-free so the functions are reusable in the evaluation notebook.

# %%
def edit_distance(a: str, b: str) -> int:
    """Levenshtein distance, O(len(a)*len(b)) dynamic programming."""
    if a == b:
        return 0
    if not a:
        return len(b)
    if not b:
        return len(a)
    prev = list(range(len(b) + 1))
    for i, ca in enumerate(a, 1):
        curr = [i]
        for j, cb in enumerate(b, 1):
            curr.append(min(prev[j] + 1,            # deletion
                            curr[j - 1] + 1,        # insertion
                            prev[j - 1] + (ca != cb)))  # substitution
        prev = curr
    return prev[-1]


def corpus_metrics(preds: list[str], refs: list[str]) -> dict:
    assert len(preds) == len(refs) and len(refs) > 0
    total_ed = sum(edit_distance(p, r) for p, r in zip(preds, refs))
    total_chars = sum(len(r) for r in refs)
    exact = sum(p == r for p, r in zip(preds, refs))
    return {
        "CER": total_ed / max(total_chars, 1),
        "ExactMatch": exact / len(refs),
        "WER": 1.0 - exact / len(refs),   # single-word samples
        "n": len(refs),
    }

# Unit checks — tiny, but they demonstrate correctness-by-construction
assert edit_distance("amoxicillin", "amoxicillin") == 0
assert edit_distance("amoxicillin", "amoxicilin") == 1
assert corpus_metrics(["abc"], ["abd"])["CER"] == 1/3

# %% [markdown]
# ## 7. Data loading
# Build the vocabulary from **training labels only**, then share it with val/test.

# %%
train_ds = WordImageDataset(CFG.data_root / CFG.train_csv, CFG.data_root / CFG.train_img_dir,
                            CFG, augment=True)
VOCAB = Vocab(train_ds.labels())
train_ds.vocab = VOCAB

val_ds = WordImageDataset(CFG.data_root / CFG.val_csv, CFG.data_root / CFG.val_img_dir,
                          CFG, vocab=VOCAB)
test_ds = WordImageDataset(CFG.data_root / CFG.test_csv, CFG.data_root / CFG.test_img_dir,
                           CFG, vocab=VOCAB)

print(f"train={len(train_ds)}  val={len(val_ds)}  test={len(test_ds)}  classes={len(VOCAB)}")

from functools import partial
_collate = partial(collate, pad_value=CFG.pad_value)
train_dl = DataLoader(train_ds, CFG.batch_size, shuffle=True,
                      num_workers=CFG.num_workers, collate_fn=_collate, drop_last=True)
val_dl   = DataLoader(val_ds, CFG.batch_size, shuffle=False,
                      num_workers=CFG.num_workers, collate_fn=_collate)
test_dl  = DataLoader(test_ds, CFG.batch_size, shuffle=False,
                      num_workers=CFG.num_workers, collate_fn=_collate)

# Sanity-visualise a batch (qualitative check that preprocessing is sensible)
xb, tb, tl, texts, fnames = next(iter(train_dl))
fig, axes = plt.subplots(2, 4, figsize=(12, 3))
for ax, img, txt in zip(axes.flat, xb, texts):
    ax.imshow(img.squeeze(0), cmap="gray"); ax.set_title(txt, fontsize=8); ax.axis("off")
plt.tight_layout(); plt.show()
# Out:
# train=3688  val=790  test=791  classes=40

# %% [markdown]
# ## 8. Training loop
#
# AdamW + gradient clipping + ReduceLROnPlateau on validation CER; best checkpoint kept
# by validation CER. `zero_infinity=True` guards against the (rare) degenerate case where
# a target is longer than the input sequence.
#
# **Understand for the viva:** why is the *log-softmax over the class dimension* required
# before `nn.CTCLoss`? (CTC expects log-probabilities; passing raw logits silently
# produces wrong gradients.)

# %%
def greedy_decode(logits: torch.Tensor, vocab: Vocab) -> list[str]:
    """logits: (T, N, C) -> list of N decoded strings."""
    idx = logits.argmax(-1).permute(1, 0)  # (N, T)
    return [vocab.decode_greedy(seq.tolist()) for seq in idx]


@torch.no_grad()
def evaluate(model, loader, vocab):
    """Returns (metrics, preds, refs, filenames). Filenames let the caller compute
    the seen-vs-unseen-vocabulary breakdown by joining against the split CSV."""
    model.eval()
    preds, refs, files = [], [], []
    for xb, _, _, texts, fnames in loader:
        logits = model(xb.to(DEVICE))
        preds += greedy_decode(logits.cpu(), vocab)
        refs += texts
        files += fnames
    return corpus_metrics(preds, refs), preds, refs, files


def train(model, train_dl, val_dl, cfg: Config, vocab: Vocab):
    model.to(DEVICE)
    ctc = nn.CTCLoss(blank=Vocab.BLANK, zero_infinity=True)
    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
    # Plateau scheduler kicks in AFTER warmup (manual warmup applied per-epoch below)
    sched = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, mode="min", factor=0.5, patience=4)

    history, best_cer, epochs_no_improve = [], float("inf"), 0
    for epoch in range(1, cfg.epochs + 1):
        # --- linear LR warmup for the first warmup_epochs ---
        if epoch <= cfg.warmup_epochs:
            warm = cfg.lr * epoch / cfg.warmup_epochs
            for g in opt.param_groups:
                g["lr"] = warm

        model.train()
        t0, running = time.time(), 0.0
        for xb, targets, target_lengths, _, _ in train_dl:
            xb = xb.to(DEVICE)
            logits = model(xb)                                  # (T, N, C) on MPS
            log_probs = logits.log_softmax(2)
            T = logits.shape[0]
            input_lengths = torch.full((xb.shape[0],), T, dtype=torch.long)
            # CTC loss has no MPS kernel: computed on CPU via fallback / explicit move
            loss = ctc(log_probs.cpu(), targets, input_lengths, target_lengths)

            opt.zero_grad(set_to_none=True)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
            opt.step()
            running += loss.item() * xb.shape[0]

        train_loss = running / len(train_dl.dataset)
        val_metrics, _, _, _ = evaluate(model, val_dl, vocab)
        if epoch > cfg.warmup_epochs:
            sched.step(val_metrics["CER"])
        history.append({"epoch": epoch, "train_loss": train_loss, **val_metrics})
        print(f"epoch {epoch:3d} | loss {train_loss:.4f} | "
              f"val CER {val_metrics['CER']:.4f} | val EM {val_metrics['ExactMatch']:.4f} | "
              f"{time.time()-t0:.1f}s")

        if val_metrics["CER"] < best_cer:
            best_cer = val_metrics["CER"]
            epochs_no_improve = 0
            torch.save({"model": model.state_dict(), "vocab": VOCAB.idx2char,
                        "config": vars(cfg) | {"data_root": str(cfg.data_root),
                                               "ckpt_dir": str(cfg.ckpt_dir)}},
                       cfg.ckpt_dir / "best.pt")
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= cfg.early_stop_patience:
                print(f"early stopping at epoch {epoch} "
                      f"(no val-CER improvement for {cfg.early_stop_patience} epochs)")
                break
    return pd.DataFrame(history)


model = CRNN(n_classes=len(VOCAB), rnn_hidden=CFG.rnn_hidden,
             rnn_layers=CFG.rnn_layers, dropout=CFG.dropout)
n_params = sum(p.numel() for p in model.parameters())
print(f"CRNN parameters: {n_params/1e6:.2f}M")

history = train(model, train_dl, val_dl, CFG, VOCAB)
# Out:
# CRNN parameters: 7.68M
# epoch   1 | loss 16.3278 | val CER 1.0000 | val EM 0.0000 | 19.6s
# epoch   2 | loss 3.5017 | val CER 1.0000 | val EM 0.0000 | 17.9s
# epoch   3 | loss 3.2368 | val CER 0.9991 | val EM 0.0000 | 17.8s
# epoch   4 | loss 3.1613 | val CER 0.9474 | val EM 0.0000 | 17.8s
# epoch   5 | loss 3.0953 | val CER 0.8799 | val EM 0.0000 | 17.8s
# epoch   6 | loss 3.0245 | val CER 0.8442 | val EM 0.0000 | 17.8s
# epoch   7 | loss 2.9730 | val CER 0.8370 | val EM 0.0000 | 17.8s
# epoch   8 | loss 2.9291 | val CER 0.8537 | val EM 0.0013 | 17.8s
# epoch   9 | loss 2.8981 | val CER 0.8363 | val EM 0.0000 | 17.8s
# epoch  10 | loss 2.8772 | val CER 0.8401 | val EM 0.0114 | 17.8s
# epoch  11 | loss 2.8629 | val CER 0.8555 | val EM 0.0000 | 17.8s
# epoch  12 | loss 2.8458 | val CER 0.8357 | val EM 0.0063 | 17.8s
# epoch  13 | loss 2.8301 | val CER 0.8251 | val EM 0.0203 | 17.9s
# epoch  14 | loss 2.8138 | val CER 0.8165 | val EM 0.0063 | 17.9s
# epoch  15 | loss 2.8002 | val CER 0.8334 | val EM 0.0000 | 18.0s
# epoch  16 | loss 2.7824 | val CER 0.8189 | val EM 0.0152 | 17.9s
# epoch  17 | loss 2.7617 | val CER 0.8247 | val EM 0.0266 | 17.8s
# epoch  18 | loss 2.7397 | val CER 0.8269 | val EM 0.0114 | 17.8s
# epoch  19 | loss 2.7086 | val CER 0.8150 | val EM 0.0278 | 17.9s
# epoch  20 | loss 2.6733 | val CER 0.7910 | val EM 0.0000 | 18.0s
# epoch  21 | loss 2.6399 | val CER 0.7798 | val EM 0.0165 | 17.9s
# epoch  22 | loss 2.5971 | val CER 0.7868 | val EM 0.0266 | 17.9s
# epoch  23 | loss 2.5684 | val CER 0.7787 | val EM 0.0253 | 17.8s
# epoch  24 | loss 2.5097 | val CER 0.7943 | val EM 0.0291 | 17.9s
# epoch  25 | loss 2.4645 | val CER 0.7714 | val EM 0.0304 | 17.9s
# epoch  26 | loss 2.4331 | val CER 0.7586 | val EM 0.0127 | 17.9s
# epoch  27 | loss 2.3760 | val CER 0.7342 | val EM 0.0177 | 18.1s
# epoch  28 | loss 2.3199 | val CER 0.7181 | val EM 0.0291 | 17.9s
# epoch  29 | loss 2.2497 | val CER 0.7043 | val EM 0.0215 | 17.9s
# epoch  30 | loss 2.1839 | val CER 0.6660 | val EM 0.0203 | 18.0s
# epoch  31 | loss 2.1299 | val CER 0.6697 | val EM 0.0253 | 17.9s
# epoch  32 | loss 2.0653 | val CER 0.6860 | val EM 0.0000 | 17.8s
# epoch  33 | loss 2.0096 | val CER 0.6761 | val EM 0.0165 | 17.9s
# epoch  34 | loss 1.9366 | val CER 0.6449 | val EM 0.0165 | 17.8s
# epoch  35 | loss 1.8649 | val CER 0.6407 | val EM 0.0076 | 18.0s
# epoch  36 | loss 1.8167 | val CER 0.6022 | val EM 0.0304 | 17.8s
# epoch  37 | loss 1.7489 | val CER 0.5987 | val EM 0.0354 | 18.0s
# epoch  38 | loss 1.6814 | val CER 0.5776 | val EM 0.0418 | 17.9s
# epoch  39 | loss 1.6340 | val CER 0.5855 | val EM 0.0291 | 17.8s
# epoch  40 | loss 1.5720 | val CER 0.5868 | val EM 0.0291 | 17.9s
# epoch  41 | loss 1.5283 | val CER 0.5760 | val EM 0.0316 | 17.8s
# epoch  42 | loss 1.4635 | val CER 0.5747 | val EM 0.0291 | 17.8s
# epoch  43 | loss 1.4136 | val CER 0.5525 | val EM 0.0316 | 17.8s
# epoch  44 | loss 1.3627 | val CER 0.6086 | val EM 0.0253 | 17.9s
# epoch  45 | loss 1.3195 | val CER 0.5421 | val EM 0.0342 | 17.8s
# epoch  46 | loss 1.2592 | val CER 0.5666 | val EM 0.0278 | 17.9s
# epoch  47 | loss 1.2232 | val CER 0.5578 | val EM 0.0278 | 17.9s
# epoch  48 | loss 1.1779 | val CER 0.5564 | val EM 0.0316 | 18.0s
# epoch  49 | loss 1.1382 | val CER 0.5426 | val EM 0.0266 | 18.0s
# epoch  50 | loss 1.0956 | val CER 0.5382 | val EM 0.0443 | 17.8s
# epoch  51 | loss 1.0728 | val CER 0.5382 | val EM 0.0329 | 17.9s
# epoch  52 | loss 1.0267 | val CER 0.5474 | val EM 0.0177 | 18.0s
# epoch  53 | loss 0.9806 | val CER 0.5201 | val EM 0.0253 | 18.0s
# epoch  54 | loss 0.9580 | val CER 0.5228 | val EM 0.0367 | 17.9s
# epoch  55 | loss 0.9219 | val CER 0.5127 | val EM 0.0456 | 17.9s
# epoch  56 | loss 0.8820 | val CER 0.4940 | val EM 0.0658 | 17.9s
# epoch  57 | loss 0.8558 | val CER 0.5050 | val EM 0.0595 | 17.9s
# epoch  58 | loss 0.8242 | val CER 0.5344 | val EM 0.0519 | 17.8s
# epoch  59 | loss 0.7885 | val CER 0.5507 | val EM 0.0266 | 17.8s
# epoch  60 | loss 0.7671 | val CER 0.6005 | val EM 0.0430 | 17.9s
# epoch  61 | loss 0.7508 | val CER 0.5457 | val EM 0.0304 | 17.8s
# epoch  62 | loss 0.6693 | val CER 0.4722 | val EM 0.0759 | 17.9s
# epoch  63 | loss 0.6292 | val CER 0.4807 | val EM 0.0810 | 17.8s
# epoch  64 | loss 0.6171 | val CER 0.4654 | val EM 0.0899 | 17.8s
# epoch  65 | loss 0.5924 | val CER 0.4781 | val EM 0.0557 | 17.8s
# epoch  66 | loss 0.5744 | val CER 0.4955 | val EM 0.0772 | 17.8s
# epoch  67 | loss 0.5647 | val CER 0.4632 | val EM 0.1076 | 17.9s
# epoch  68 | loss 0.5450 | val CER 0.4770 | val EM 0.1089 | 17.8s
# epoch  69 | loss 0.5320 | val CER 0.4781 | val EM 0.0481 | 18.0s
# epoch  70 | loss 0.5146 | val CER 0.4882 | val EM 0.0696 | 17.8s
# epoch  71 | loss 0.5047 | val CER 0.4990 | val EM 0.0772 | 17.8s
# epoch  72 | loss 0.4914 | val CER 0.4480 | val EM 0.1481 | 17.8s
# epoch  73 | loss 0.4735 | val CER 0.4647 | val EM 0.1139 | 17.8s
# epoch  74 | loss 0.4807 | val CER 0.5397 | val EM 0.0329 | 17.8s
# epoch  75 | loss 0.4699 | val CER 0.4634 | val EM 0.1228 | 17.8s
# epoch  76 | loss 0.4528 | val CER 0.4480 | val EM 0.1506 | 17.9s
# epoch  77 | loss 0.4363 | val CER 0.4662 | val EM 0.0937 | 17.8s
# epoch  78 | loss 0.4052 | val CER 0.4394 | val EM 0.1608 | 17.9s
# epoch  79 | loss 0.3859 | val CER 0.4357 | val EM 0.1709 | 17.8s
# epoch  80 | loss 0.3766 | val CER 0.4398 | val EM 0.1759 | 17.8s
# epoch  81 | loss 0.3641 | val CER 0.4286 | val EM 0.1772 | 17.9s
# epoch  82 | loss 0.3520 | val CER 0.4268 | val EM 0.1949 | 17.8s
# epoch  83 | loss 0.3469 | val CER 0.4257 | val EM 0.1987 | 17.8s
# epoch  84 | loss 0.3411 | val CER 0.4304 | val EM 0.1924 | 17.8s
# epoch  85 | loss 0.3367 | val CER 0.4326 | val EM 0.2013 | 17.8s
# epoch  86 | loss 0.3371 | val CER 0.4286 | val EM 0.1772 | 17.9s
# epoch  87 | loss 0.3212 | val CER 0.4268 | val EM 0.2038 | 17.9s
# epoch  88 | loss 0.3151 | val CER 0.4249 | val EM 0.1962 | 17.8s
# epoch  89 | loss 0.3034 | val CER 0.4260 | val EM 0.1937 | 17.8s
# epoch  90 | loss 0.3022 | val CER 0.4205 | val EM 0.2127 | 17.8s
# epoch  91 | loss 0.2982 | val CER 0.4313 | val EM 0.1924 | 18.5s
# epoch  92 | loss 0.2891 | val CER 0.4275 | val EM 0.1899 | 46.9s
# epoch  93 | loss 0.2838 | val CER 0.4280 | val EM 0.1911 | 21.5s
# epoch  94 | loss 0.2763 | val CER 0.4229 | val EM 0.2241 | 17.9s
# epoch  95 | loss 0.2691 | val CER 0.4328 | val EM 0.1785 | 17.9s
# epoch  96 | loss 0.2608 | val CER 0.4191 | val EM 0.2203 | 17.9s
# epoch  97 | loss 0.2497 | val CER 0.4224 | val EM 0.2203 | 17.8s
# epoch  98 | loss 0.2476 | val CER 0.4196 | val EM 0.2253 | 17.8s
# epoch  99 | loss 0.2434 | val CER 0.4185 | val EM 0.2215 | 17.8s
# epoch 100 | loss 0.2403 | val CER 0.4205 | val EM 0.2152 | 17.8s
# epoch 101 | loss 0.2364 | val CER 0.4165 | val EM 0.2215 | 17.8s
# epoch 102 | loss 0.2350 | val CER 0.4147 | val EM 0.2329 | 17.8s
# epoch 103 | loss 0.2307 | val CER 0.4233 | val EM 0.2139 | 17.9s
# epoch 104 | loss 0.2275 | val CER 0.4200 | val EM 0.2342 | 17.9s
# epoch 105 | loss 0.2229 | val CER 0.4181 | val EM 0.2316 | 17.9s
# epoch 106 | loss 0.2201 | val CER 0.4214 | val EM 0.2177 | 17.8s
# epoch 107 | loss 0.2154 | val CER 0.4196 | val EM 0.2253 | 17.8s
# epoch 108 | loss 0.2111 | val CER 0.4154 | val EM 0.2367 | 17.8s
# epoch 109 | loss 0.2104 | val CER 0.4165 | val EM 0.2329 | 17.8s
# epoch 110 | loss 0.2073 | val CER 0.4161 | val EM 0.2304 | 18.0s
# epoch 111 | loss 0.2067 | val CER 0.4114 | val EM 0.2380 | 17.9s
# epoch 112 | loss 0.2045 | val CER 0.4152 | val EM 0.2367 | 17.9s
# epoch 113 | loss 0.2052 | val CER 0.4185 | val EM 0.2316 | 17.9s
# epoch 114 | loss 0.2013 | val CER 0.4136 | val EM 0.2456 | 18.0s
# epoch 115 | loss 0.2020 | val CER 0.4143 | val EM 0.2380 | 17.8s
# epoch 116 | loss 0.1984 | val CER 0.4156 | val EM 0.2354 | 17.9s
# epoch 117 | loss 0.1938 | val CER 0.4106 | val EM 0.2405 | 18.0s
# epoch 118 | loss 0.1960 | val CER 0.4106 | val EM 0.2392 | 18.0s
# epoch 119 | loss 0.1944 | val CER 0.4143 | val EM 0.2342 | 18.0s
# epoch 120 | loss 0.1924 | val CER 0.4145 | val EM 0.2405 | 17.8s

# %% [markdown]
# ## 9. Learning curves

# %%
fig, ax1 = plt.subplots(figsize=(8, 4))
ax1.plot(history["epoch"], history["train_loss"], label="train CTC loss")
ax1.set_xlabel("epoch"); ax1.set_ylabel("CTC loss")
ax2 = ax1.twinx()
ax2.plot(history["epoch"], history["CER"], color="tab:red", label="val CER")
ax2.set_ylabel("val CER")
fig.legend(loc="upper right"); plt.title("Baseline CRNN training"); plt.show()

# %% [markdown]
# ## 10. Test-set evaluation & error analysis
#
# Reload the **best** checkpoint (not the last epoch) before final evaluation, and look at
# the failure cases — the confusion pairs you find here (e.g. visually similar medicine
# names) are the qualitative evidence for the Gap Analysis chapter.

# %%
ckpt = torch.load(CFG.ckpt_dir / "best.pt", map_location="cpu")
model.load_state_dict(ckpt["model"]); model.to(DEVICE)

test_metrics, test_preds, test_refs, test_files = evaluate(model, test_dl, VOCAB)
print("BASELINE CRNN — test (overall):",
      {k: round(v, 4) if isinstance(v, float) else v for k, v in test_metrics.items()})

# --- Seen vs unseen vocabulary breakdown -------------------------------------------
# Join predictions back to the test CSV's `seen_in_train` flag (written by Notebook 00).
# This separates "could the model recognise a name it trained on" from the harder
# open-vocabulary case of names never seen in training — the core difficulty of this
# dataset and a key result for the evaluation chapter.
test_df = pd.read_csv(CFG.data_root / CFG.test_csv)
seen_map = dict(zip(test_df[CFG.img_col].astype(str), test_df["seen_in_train"]))

groups = {"seen": ([], []), "unseen": ([], [])}
for pred, ref, fn in zip(test_preds, test_refs, test_files):
    key = "seen" if seen_map.get(fn, False) else "unseen"
    groups[key][0].append(pred); groups[key][1].append(ref)

print("\nbreakdown by vocabulary:")
for key, (P, R) in groups.items():
    if R:
        gm = corpus_metrics(P, R)
        print(f"  {key:6s} (n={gm['n']:3d}): CER {gm['CER']:.4f} | ExactMatch {gm['ExactMatch']:.4f}")

errors = [(r, p, edit_distance(p, r)) for p, r in zip(test_preds, test_refs) if p != r]
errors.sort(key=lambda e: -e[2])
err_df = pd.DataFrame(errors, columns=["reference", "prediction", "edit_distance"])
err_df.to_csv(CFG.ckpt_dir / "baseline_errors.csv", index=False)
print(f"\n{len(errors)} errors / {len(test_refs)} samples. Worst 15:")
err_df.head(15)
# Out:
# BASELINE CRNN — test (overall): {'CER': 0.4305, 'ExactMatch': 0.2263, 'WER': 0.7737, 'n': 791}
#
# breakdown by vocabulary:
#   seen   (n=615): CER 0.3534 | ExactMatch 0.2894
#   unseen (n=176): CER 0.6692 | ExactMatch 0.0057
#
# 612 errors / 791 samples. Worst 15:
#           reference    prediction  edit_distance
# 0    flucloxacillin     paxoseran             12
# 1   pulse tri-omega         penen             12
# 2     lbp following        cennon             11
# 3      cifotil plus          fnon             11
# 4      atorvastatin        celeix             11
# 5   tab.aristovif-3       calilo-             11
# 6      atorvastatin       isicmer             11
# 7      plaqriw plus     axopnaner             11
# 8     resitfex plus      ralfa md             10
# 9      cora dx vitr      cenio al             10
# 10     prednisolone        motoin             10
# 11     terbinaforce       rontien             10
# 12      voligel max       nanupld             10
# 13           apeclo  calisiltupsd             10
# 14   spironolactone       tantooe             10

# %% [markdown]
# ## 11. Single-image inference
# Utility for the viva demo and for spot-checking pharmacy images later.

# %%
@torch.no_grad()
def predict_image(path: str | Path, model: nn.Module, vocab: Vocab, cfg: Config) -> str:
    # Must mirror training preprocessing exactly: aspect-preserve resize + pad to canvas
    img = Image.open(path).convert("L")
    w, h = img.size
    new_w = min(max(1, int(round(w * cfg.img_height / h))), cfg.img_width)
    img = img.resize((new_w, cfg.img_height), Image.BILINEAR)
    canvas = Image.new("L", (cfg.img_width, cfg.img_height), color=255)
    canvas.paste(img, (0, 0))
    x = torch.from_numpy(np.array(canvas, dtype=np.float32) / 255.0)[None, None].to(DEVICE)
    model.eval()
    return greedy_decode(model(x).cpu(), vocab)[0]

# Example (uncomment with a real path):
# print(predict_image(CFG.data_root / CFG.test_img_dir / "example.png", model, VOCAB, CFG))

# %% [markdown]
# ## 12. What to record for the thesis (do this now, not at write-up)
#
# 1. **Methodology table:** every value in `Config`, parameter count, device, torch version.
# 2. **Results table:** test CER / WER / Exact Match with the number of test samples.
# 3. **Error inventory:** `baseline_errors.csv` — categorise the top errors (look-alike
#    confusion vs illegibility vs preprocessing artefact). This feeds Gap Analysis §(a).
# 4. **Training cost:** wall-clock per epoch on the M4 Pro — evidence for the
#    "feasible local training" claim in the methodology.
#
# **Next notebook (02):** hybrid CNN + Transformer encoder with joint CTC–attention and
# lexicon-constrained decoding, evaluated with the *same* `corpus_metrics` functions and
# the *same* splits so the comparison is controlled.
